# %%
import numpy as np

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.head(8)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
sns.scatterplot(df, y='price_range', x='battery_power') #i think battery power is not that necessary for predicting
# Out:
# <Axes: xlabel='battery_power', ylabel='price_range'>

# %%
sns.scatterplot(df, y='price_range', x='clock_speed') #same as batter power
# Out:
# <Axes: xlabel='clock_speed', ylabel='price_range'>

# %%
sns.scatterplot(df, y='price_range', x='dual_sim')
# Out:
# <Axes: xlabel='dual_sim', ylabel='price_range'>

# %%
sns.scatterplot(df, y='price_range', x='ram') # now this shows the real deal
# Out:
# <Axes: xlabel='ram', ylabel='price_range'>

# %%
sns.boxplot(df, x='price_range', y='ram')
# Out:
# <Axes: xlabel='price_range', ylabel='ram'>

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.scatterplot(df, y='price_range', x='touch_screen')
# Out:
# <Axes: xlabel='touch_screen', ylabel='price_range'>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['price_range'])
y=df['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(
 X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score

# %%
model_dt = DecisionTreeClassifier(random_state=42)
model_dt.fit(X_train, y_train)
y_pred_dt = model_dt.predict(X_test)

model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_train, y_train)
y_pred_rf = model_rf.predict(X_test)

for name, y_pred in [("decision_tree" , y_pred_dt), ("random_forest" , y_pred_rf)]:
    print(name)
    print('accuracy :' ,accuracy_score(y_test, y_pred))
# Out:
# decision_tree
# accuracy : 0.8196969696969697
# random_forest
# accuracy : 0.8742424242424243

# %%
print("f1_score:", f1_score(y_test, y_pred, average='macro'))   # macro since you have 4 classes
print(confusion_matrix(y_test, y_pred))
# Out:
# f1_score: 0.8727101667762843
# [[160   9   0   0]
#  [ 11 137  14   0]
#  [  0  17 127  18]
#  [  0   0  14 153]]

# %%
importances = pd.Series(model_rf.feature_importances_, index=X.columns)
importances.sort_values(ascending=False).head(10)
# Out:
# ram              0.463216
# battery_power    0.076568
# px_height        0.057352
# px_width         0.056903
# mobile_wt        0.040403
# int_memory       0.037844
# talk_time        0.031856
# pc               0.031663
# sc_h             0.029842
# sc_w             0.029560
# dtype: float64

# %%
import joblib

joblib.dump(model_rf, "mobile_price_model.pkl")
joblib.dump(X.columns.tolist(), "mobile_price_columns.pkl")
# Out:
# ['mobile_price_columns.pkl']
